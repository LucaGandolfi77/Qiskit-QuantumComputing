# %% [markdown]
# # all_in_one.ipynb
# Questo notebook mostra il contenuto completo di ogni file .py del progetto.
# Ogni sezione legge e stampa il sorgente corrispondente dal filesystem per evitare problemi di escaping nel file JSON del notebook.

# %% [markdown]
# ## admm_solver.py

# %%
from pathlib import Path
p = Path('admm_solver.py')
print(p.resolve())
print('-' * 80)
print(p.read_text(encoding='utf-8'))

# %% [markdown]
# ## inspect_subproblems.py

# %%
from pathlib import Path
p = Path('inspect_subproblems.py')
print(p.resolve())
print('-' * 80)
print(p.read_text(encoding='utf-8'))

# %% [markdown]
# ## main.py

# %%
from pathlib import Path
p = Path('main.py')
print(p.resolve())
print('-' * 80)
print(p.read_text(encoding='utf-8'))

# %% [markdown]
# ## problem_formulation.py

# %%
from pathlib import Path
p = Path('problem_formulation.py')
print(p.resolve())
print('-' * 80)
print(p.read_text(encoding='utf-8'))

# %% [markdown]
# ## results_analysis.py

# %%
from pathlib import Path
p = Path('results_analysis.py')
print(p.resolve())
print('-' * 80)
print(p.read_text(encoding='utf-8'))

# %% [markdown]
# ## scaling_study/config_generator.py

# %%
from pathlib import Path
p = Path('scaling_study/config_generator.py')
print(p.resolve())
print('-' * 80)
print(p.read_text(encoding='utf-8'))

# %% [markdown]
# ## scaling_study/scaling_runner.py

# %%
from pathlib import Path
p = Path('scaling_study/scaling_runner.py')
print(p.resolve())
print('-' * 80)
print(p.read_text(encoding='utf-8'))

# %% [markdown]
# ## scaling_study/single_run.py

# %%
from pathlib import Path
p = Path('scaling_study/single_run.py')
print(p.resolve())
print('-' * 80)
print(p.read_text(encoding='utf-8'))
